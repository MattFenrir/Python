# %% [markdown]
# # PYTHON
#
# #### PROGRAMAÇÃO ORIENTADA A OBJETO - POO (OOP -en)

# %% [markdown]
# JANELA
#     ATRIBUTOS / CARACTERÍSTICAS
#         - MATERIAL ->
#         - FORMATO ->
#         - COR ->
#         - ALTURA ->
#         - LARGURA ->
#         - COMPRIMENTO ->
#         - TEMPERATURA ->
#
# COMPORTAMENTOS / MÉTODOS / AÇÕES
#         - ABRIR()
#         - FECHAR()
#         - SUBIR()
#         - DESCER()
#         - VERIFICAR()
#
# ESTADO
#         - conservação -> (nova, velha, conservada, quebrada)

# %% [markdown]
# PESSOA
#     - ATRIBUTOS
#         - ALTURA
#         - PESO
#         - ETNIA
#         - OLHOS
#         - ENDEREÇO
#         - TELEFONE
#         - PORTE
#         - CPF
#         - IDENTIDADE
#         - CABELO
#         - DATA_DE_NASCIMENTO
#         - NOME_DA_MÃE
#         - NOME_DO_PAI
#
#     - MÉTODOS
#         - ANDAR()
#         - FALAR()
#         - CORRER()
#         - APRENDER()
#         - DIRIGIR()
#
#     - ESTADO
#         - CANSADO
#         - CASADO
# -------------------------------------------------------
#     CARRO
#         ATRIBUTOS
#             - PESO
#             - QNT_PORTAS
#             - MOTOR
#             - LARGURA
#             - ALTURA
#             - MOTOR
#             - MARCA
#             - CARBURADOR
#             - ARO
#             - NUM_CHASSI
#             - VELOCIDADE
#             - COR
#             - ANO
#
#         MÉTODOS
#             - ACELERAR()
#             - FREIAR()
#             - DIREÇÃO()
#             - ABRIR_PORTA()
#             - LIGAR()
#             - DESLIGAR()
#
#         ESTADO
#             ligado/desligado
#             parado/andando
#             funcionando/ruim
# ------------------------------------------------------
#
# CALENDÁRIO/EVENTO
#     ATRIBUTOS
#         - DIA
#         - HORÁRIO
#         - MÊS
#         - LOCAL
#
#     MÉTODOS
#         COMPRAR INGRESSO()
#         MARCAR()
#         DESMARCAR()
#
#     ESTADO
#         status -> (ADIADO, ACONTECENDO, ATRASADO, FINALIZADO, CANCELADO)

# %% [markdown]
# # ESCOLA
#     CONTAS
#         ATRIBUTOS
#         - DATA VENC
#         - VALOR
#         - STATUS
#
#     PROFESSOR
#         ATRIBUTOS
#         - MATÉRIA
#         - NOME
#         - SALÁRIO
#         - TELEFONE
#         - IDADE
#         - DATA_CONT
#
#         MÉTODOS
#         - ENSINANDO()
#         - EM_AULA()
#         - DEMITIR()
#
#         ESTADO
#         - SITUAÇÃO -> (DEMITIDO)
#
#     ALUNOS
#         ATRIBUTOS
#         - SÉRIE
#         - NOME
#         - MENSALIDADE
#         - TELEFONE_RESP
#         - IDADE
#
#         MÉTODOS
#         - LANCHANDO()
#         - ESTUDANDO()
#
#         ESTADO
#             situação -> (FALTA, NA AULA)
#
#     MATERIAIS
#         ATRIBUTOS
#         - VALOR
#         - DATA_COMP
#         - QNT
#
#     MATERIAIS_VENDA
#         ATRIBUTOS
#         - COD
#         - NOME
#         - VALOR
#         - QNT
#         - SETOR
#
#         MÉTODOS
#         VERIFICA ESTOQUE()
#         VERIFICA_SETOR()
#         VENDER()
#
#     FUNCIONÁRIOS
#         ATRIBUTOS
#             NOME
#             TELEFONE
#             SALÁRIO
#             DATA_CONT
#             AREA

# %% [markdown]
# CONSULTÓRIO MÉDICO
#     MÉDICOS
#         ATRIBUTOS
#             - NOME
#             - ESPEC
#             - SALÁRIO
#             - DIA_TRABA
#             - TELEFONE
#             - EMAIL
#             - CRM
#
#         MÉTODOS
#             LISTAR_MEDICOS()
#             LISTAR_COMP()
#             QNT_ESP()
#
#         ESTADO
#
#     PACIENTE
#         ATRIBUTOS
#             - NOME
#             ......
#
#     CONSULTA
#         ATRIBUTOS
#         - NOME MÉDICO
#         - CODMEDIC
#         - NOME PACIENTE
#         - VALOR
#         - DATA
#         - STATUS
#         - PRONTUÁRIO
#
#         MÉTODOS
#         MARCAR()
#         LISTAR()
#         CONSULTAS_PACIENTES()
#         DESMARCAR
#
#     EQUIPAMENTOS
#         ATRIBUTOS
#
#     FUNCIONÁRIOS
#         ATRIBUTOS
#
#     CONTAS
#         ATRIBUTOS

# %% [markdown]
# LOJA DE INFORMÁTICA
#
#     PRODUTOS
#         ATRIBUTOS
#             - VALOR
#             - PESO
#             - NOME
#             - CÓDIGO
#             - MARCA
#             - COR
#             - ESPECIFICAÇÃO
#
#         MÉTODOS
#             LISTAR()
#             VERIFICAR_EST()
#
#     VENDAS
#         ATRIBUTOS
#             - VALOR TOTAL
#             - PRODUTOS
#             - ENDEREÇO
#             - FORMA
#             - VENDEDOR
#
#         MÉTODOS
#             - COMPRAR()
#             - VERIFICAR()
#             - ALTERAR_STATUS()
#
#         ESTADO
#             STATUS -> (AGUARDANDO PG, ENVIADO, ENTREGUE, CANCELADO, PERDIDO, EM TROCA)
#
#     VENDEDOR
#         ATRIBUTOS ....

# %% [markdown]
# LOJA MCDONALDS
#
#     PRODUTOS
#         ATRIBUTOS
#             - CÓDIGO
#             - NOME
#             - VALOR
#             - DESCRIÇÃO
#             - TAMANHO
#             - PESO
#             - QNT_ESTOQUE
#             - TIPO
#
#         MÉTODO
#             - LISTAR_PRODUTOS()
#
#         VENDA
#             ATRIBUTO
#                 - COD
#                 - VALOR TOTAL
#                 - LISTA PRODUTOS
#                 - VENDEDOR
#                 - FORMA_PG
#                 - STATUS
#             MÉTODO
#                 ALTERAR_STATUS()
#                 VENDER()
#             ESTADO
#                 STATUS_VENDA
#
#         PROMOÇÃO
#             ATRIBUTOS
#                 - COD
#                 - NOME (AGOSTO20)
#                 - VALOR_DESCONTO
#
#             MÉTODOS
#                 LISTA()
#
#             ESTADO
#                 STATUS ->
#
#         FUNCIONÁRIOS
#
#         CONTAS
#
#         EQUIPAMENTOS
